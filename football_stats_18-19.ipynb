# %%
# Imports 
import pandas as pd

# %%
# get files to load

e_file = "resources/english.csv"
g_file = "resources/german.csv"
s_file = "resources/spanish.csv"

# %%
#load data into pandas dataframe

english = pd.read_csv(e_file)
german = pd.read_csv(g_file)
spanish = pd.read_csv(s_file)

# %%
english.head()
# Out:
#   Unnamed: 0                               Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0         Rk                                   Player     Nation        Pos
# 1          1  Patrick van Aanholt\Patrick-van-Aanholt     nl NED         DF
# 2          2              Sergio Agüero\Sergio-Aguero     ar ARG         FW
# 3          3                    Nathan Aké\Nathan-Ake     nl NED         DF
# 4          4          Marc Albrighton\Marc-Albrighton    eng ENG       FWMF
#
#         Unnamed: 4 Unnamed: 5 Unnamed: 6 Playing Time Playing Time.1  \
# 0            Squad        Age       Born           MP         Starts
# 1   Crystal Palace         27       1990           36             36
# 2  Manchester City         30       1988           33             31
# 3      Bournemouth         23       1995           38             38
# 4   Leicester City         28       1989           27             18
#
#   Playing Time.2  ... Per 90 Minutes.4 Expected Expected.1 Expected.2  \
# ...

# %%
german.head()
# Out:
#   Unnamed: 0                   Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0         Rk                       Player     Nation        Pos
# 1          1      Issah Abbas\Issah-Abbas     gh GHA         FW
# 2          2  David Abraham\David-Abraham     ar ARG         DF
# 3          3    Amir Abrashi\Amir-Abrashi     al ALB         MF
# 4          4      Tyler Adams\Tyler-Adams     us USA         MF
#
#        Unnamed: 4 Unnamed: 5 Unnamed: 6 Playing Time Playing Time.1  \
# 0           Squad        Age       Born           MP         Starts
# 1        Mainz 05         19       1998            1              0
# 2  Eint Frankfurt         32       1986           17             17
# 3        Freiburg         28       1990           10              9
# 4      RB Leipzig         19       1999           10              8
#
#   Playing Time.2  ... Per 90 Minutes.4 Expected Expected.1 Expected.2  \
# 0            Min  ...           G+A-PK       xG       npxG         xA
# ...

# %%
spanish.head()
# Out:
#   Unnamed: 0                     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0         Rk                         Player     Nation        Pos
# 1          1      Antonio Adán\Antonio-Adan     es ESP         GK
# 2          2                      Aday\Aday     es ESP       DFMF
# 3          3      Aritz Aduriz\Aritz-Aduriz     es ESP         FW
# 4          4  Luis Advíncula\Luis-Advincula     pe PER         DF
#
#         Unnamed: 4 Unnamed: 5 Unnamed: 6 Playing Time Playing Time.1  \
# 0            Squad        Age       Born           MP         Starts
# 1  Atlético Madrid         31       1987            1              1
# 2           Girona         30       1987           10              8
# 3    Athletic Club         37       1981           20             10
# 4   Rayo Vallecano         28       1990           28             27
#
#   Playing Time.2  ... Per 90 Minutes.4 Expected Expected.1 Expected.2  \
# 0            Min  ...           G+A-PK       xG       npxG         xA
# ...
